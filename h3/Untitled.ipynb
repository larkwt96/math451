# %%
# %matplotlib inline

# %%
run p1.py
# Out:
# Problem 1
# (a)
# Output for A_10
# After 100 iterations...
# With random initial x(0)
# Amplification factor at iteration 0 = 2.823434471522247
# Amplification factor at iteration 10 = 3.776244272082823
# Amplification factor at iteration 20 = 3.8502425938122418
# Amplification factor at iteration 30 = 3.87824447822332
# Amplification factor at iteration 40 = 3.910833814211329
# Amplification factor at iteration 50 = 3.91477027127881
# Amplification factor at iteration 60 = 3.9168359055943562
# Amplification factor at iteration 70 = 3.9178960069554956
# Amplification factor at iteration 80 = 3.9184349299368733
# Amplification factor at iteration 90 = 3.9187077409757345
# Amplification factor = 3.9188365606394937
# Output for A_20
# After 100 iterations...
# With random initial x(0)
# Amplification factor at iteration 0 = 2.9139049818845146
# Amplification factor at iteration 10 = 3.7856752874638633
# Amplification factor at iteration 20 = 3.8456548217900126
# ...

# %%
run p2.py
# Out:
# Problem 2
# Overflow detected breaking at k = 513
# Largest k for which relative error of the approximated mu values is greater than 1/1000:
# k = 467
# Final amplification factor = 3.997819176154783
# I'm guessing the k value is large due to floating point inaccuracies. From the graph, compared to 1.c., it seems to converge slightly faster.

# %%
run p3.py
# Out:
# Problem 3
# (a)
# Initial v = [-9.35838929  9.4506708   3.20749152]
# After 1000 iterations
# Final amplification factor = 2.0
# Final v = [ -9.90235454e-001   1.00000000e+000   3.16743140e-302]
#
# Initial v = [ 7.0940394  -2.80071953 -8.54902616]
# After 1000 iterations
# Final amplification factor = 2.0
# Final v = [  1.00000000e+000  -3.94798981e-001  -1.12467589e-301]
#
# Initial v = [ 6.60431161 -3.65709434 -8.5905059 ]
# After 1000 iterations
# Final amplification factor = 2.0
# Final v = [  1.00000000e+000  -5.53743457e-001  -1.21393524e-301]
#
# Initial v = [-1.51784593  9.92435675  4.49197368]
# After 1000 iterations
# Final amplification factor = 2.0
# Final v = [ -1.52941492e-001   1.00000000e+000   4.22414845e-302]
#
# Initial v = [ 9.98891979  9.17945886  4.97694622]
# After 1000 iterations
# Final amplification factor = 2.0
# Final v = [  1.00000000e+000   9.18964118e-001   4.64995508e-302]
#
# Initial v = [ 3.16578029 -4.00953081  8.49089513]
# After 1000 iterations
# ...
